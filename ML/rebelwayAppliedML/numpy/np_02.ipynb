# %%
import numpy as np

# %%
a = [[1,2,3] ,[4,5,6],[7,8,9]]
a
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
b = np.array(a)
print(b)
b.T
# Out:
# [[1 2 3]
#  [4 5 6]
#  [7 8 9]]
# array([[1, 4, 7],
#        [2, 5, 8],
#        [3, 6, 9]])

# %%
c = np.array([
    [3,5,7],
    [1,5,9],
    [1,2,3]
])
c
# Out:
# array([[3, 5, 7],
#        [1, 5, 9],
#        [1, 2, 3]])

# %%
d = b.dot(c)
d
# Out:
# array([[  8,  21,  34],
#        [ 23,  57,  91],
#        [ 38,  93, 148]])

# %%
b @ c
# Out:
# array([[  8,  21,  34],
#        [ 23,  57,  91],
#        [ 38,  93, 148]])

# %%
f = np.where(d<10,d,d*10)
